# %% [markdown]
# # library

# %% [markdown]
# # connecting with google chrome

# %%
driver=Chrome(r'C:\Users\hamza lagramez\Desktop\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.twitter.com/login')

# %% [markdown]
# # enter ur mail

# %%
username=driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div[2]/form/div/div[1]/label/div/div[2]/div/input')
username.send_keys('hamzalagramez7@gmail.com')

# %% [markdown]
# # enter ur password

# %%
passwrd=getpass()
# Out:
# ········

# %%
psswrd=driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div[2]/form/div/div[2]/label/div/div[2]/div/input')
psswrd.send_keys(passwrd)

# %%
psswrd.send_keys(Keys.RETURN)

# %% [markdown]
# # tag that u want

# %%
search_bar=driver.find_element_by_xpath('//input[@data-testid="SearchBox_Search_Input"]')
search_bar.send_keys('#isreal')

# %%
search_bar.send_keys(Keys.RETURN)

# %% [markdown]
# # enter ur post that u want

# %%
#dir post li 3ajbakk
driver.get('https://twitter.com/nytimes/status/1394673844661727237')

# %%
# !pip install bson
# Out:
# ...
#   Created wheel for bson: filename=bson-0.5.10-py3-none-any.whl size=11979 sha256=fa120b3e2b426d10a15bcffa135788c7d4648b7220e0bf194996f78f3ae62962
#   Stored in directory: c:\users\hamza lagramez\appdata\local\pip\cache\wheels\da\19\9b\fef96802b64ed0ef00e216c465846e30cb4f3e2070c297d169
# Successfully built bson
# ...

# %%
import csv
import pandas as pd
from getpass import getpass
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import Chrome
from ast import literal_eval
from time import sleep
import json
#from bson import json_util

# %%
def scraping_tweet(card):
    usernam=card.find_element_by_xpath('.//span').text
    try:
        date=card.find_element_by_xpath('.//time').get_attribute('datetime')
        reply_cnt = card.find_element_by_xpath('.//div[@data-testid="reply"]').text
        retweet_cnt = card.find_element_by_xpath('.//div[@data-testid="retweet"]').text
        like_cnt = card.find_element_by_xpath('.//div[@data-testid="like"]').text
        text =card.find_element_by_xpath('.//div[2]/div[2]/div[2]/div[1]').text
    except NoSuchElementException:
        return 0
    try:
        text =card.find_element_by_xpath('.//div[2]/div[2]/div[2]/div[1]').text
    except NoSuchElementException:
        return NAN
        
    tweet=(usernam, date, reply_cnt, retweet_cnt,like_cnt,text  )
    return tweet

# %%
def web_scraping(url):
    driver=Chrome(r'C:\Users\hamza lagramez\Desktop\chromedriver_win32\chromedriver.exe')
    driver.get(url)
    comments = []
    tweet_ids = set()

    last_position = driver.execute_script("return window.pageYOffset;")
    scrolling = True

    while scrolling:
        page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]')
        #nb = page_cards[0].find_element_by_xpath('.//div[@data-testid="retweet"]').text
        for card in page_cards:
            tweet = scraping_tweet(card)
            if tweet:
                tweet_id=''.join(tweet)
                if tweet_id not in tweet_ids:
                    tweet_ids.add(tweet_id)
                    comments.append(tweet)


        scroll_attempt = 0
        while True:
            # check scroll position
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(2)
            curr_position = driver.execute_script("return window.pageYOffset;")
            if last_position == curr_position:
                scroll_attempt += 1

                # end of scroll region
                if scroll_attempt >= 3:
                    scrolling = False
                    break
                else:
                    sleep(2) # attempt another scroll
            else:
                last_position = curr_position
                break
    driver.close()
    return comments

# %%
web_scraping('https://twitter.com/garyvee/status/1395363244848603136')
# Out:
# [('𝐂𝐇𝐄𝐅 𝐋𝐈𝐙𝐄𝐓𝐓𝐄',
#   '2021-05-20T12:58:49.000Z',
#   '',
#   '',
#   '4',
#   'I’m trying to go as well. '),
#  ('Brandon D Newton',
#   '2021-05-20T12:58:55.000Z',
#   '',
#   '',
#   '3',
#   'That’s awesome! Bringing back my childhood'),
#  ('Camron Axel',
#   '2021-05-20T12:59:01.000Z',
#   '',
#   '',
#   '',
#   'age plant car slip segment whole require eight require'),
#  ('Dirty-Six',
#   '2021-05-20T12:59:06.000Z',
#   '',
#   '',
#   '3',
#   'Awesome  wish you lot of fun '),
#  ('Squids Cards', '2021-05-20T12:59:08.000Z', '', '', '3', 'See ya there :)'),
#  ('Brandon',
#   '2021-05-20T12:59:10.000Z',
#   '',
#   '',
#   '3',
#   'Cant wait!! My local \n@CSASHOWS\n show is this weekend I’m hype for that also'),
#  ('Jacky Hooi', '2021-05-20T12:59:14.000Z', '', '', '1', ''),
#  ('Santiago Leon - Web Developer - sleon productions',
#   '2021-05-20T12:59:15.000Z',
#   '',
#   '',
#   '2',
#   'Stay safe!'),
#  ('eddyiskongz',
#   '2021-05-20T12:59:15.000Z',
#   '1',
#   '',
# ...

# %%
# close the web driver
driver.close()

# %%
df=pd.DataFrame(comments)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3f2c1fec5882> in <module>
# ----> 1 df=pd.DataFrame(comments)
#
# NameError: name 'comments' is not defined

# %%
df.shape
# Out:
# (0, 0)

# %%
df.head(30)
# Out:
#                      0                         1  2 3  4  \
# 0       shazdehkhanoom  2021-05-18T15:20:27.000Z
# 1             Tommyトミー  2021-05-18T15:20:32.000Z  2    5
# 2           Mrs Con Gà  2021-05-18T15:20:50.000Z
# 3                   A.  2021-05-18T15:21:21.000Z       1
# 4             Brittany  2021-05-18T15:21:30.000Z       1
# 5    Dr Mujeeb Bangash  2021-05-18T15:21:40.000Z  1    5
# 6         Gaurav Singh  2021-05-18T15:22:50.000Z
# 7      Garrett Moffitt  2021-05-18T15:22:56.000Z       1
# 8                  Mac  2021-05-18T15:23:41.000Z       4
# 9            Diego DAI  2021-05-18T15:24:02.000Z
# 10              Renata  2021-05-18T15:25:35.000Z
# 11  fight back or move  2021-05-18T15:25:47.000Z       4
# 12        Minhaj Ahmed  2021-05-18T15:27:25.000Z  1    1
# 13             Ann Sea  2021-05-18T15:31:28.000Z
# 14       Nunchaku Dude  2021-05-18T15:36:20.000Z
# 15       Enrique Eliud  2021-05-18T16:02:38.000Z
#
#                                                     5
# ...

# %%
#wa 4itamn 5alass tacoss HHHHHHHHHH

# %%
df.to_csv('scrapi.csv')
